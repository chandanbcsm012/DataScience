# %%
import pandas as pd

# %%
pd.read_csv('products.csv')
# Out:
#                                           Name  ShortDescription  \
# 0                  1006    Screw, Nuts & Bolts               NaN
# 1                   1087     Mystry Egg Blocks               NaN
# 2             12064        5 Activity Stackers               NaN
# 3                  2018             Play Dough               NaN
# 4                        2035        Flip Kick               NaN
# 5                  2083             Play Dough               NaN
# 6                  2086             Play Dough               NaN
# 7         2093           Play Dough - Food Set               NaN
# 8         2094         Play Dough - Animal Set               NaN
# 9                2097     Slope Tumbler Roller               NaN
# 10                  22004  Stack n Tumble Doll               NaN
# 11                 22006      Glutting Giraffe               NaN
# 12                         22050    Melody Mix               NaN
# ...
